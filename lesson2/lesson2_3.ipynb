# %%
import math 
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint

r = requests.get('https://api.github.com/events')
pprint(r.text)
# Out:
# ('[{"id":"51910975226","type":"PushEvent","actor":{"id":180724571,"login":"ahmed18837","display_login":"ahmed18837","gravatar_id":"","url":"https://api.github.com/users/ahmed18837","avatar_url":"https://avatars.githubusercontent.com/u/180724571?"},"repo":{"id":989313121,"name":"ahmed18837/RestaurantsManagementSystem","url":"https://api.github.com/repos/ahmed18837/RestaurantsManagementSystem"},"payload":{"repository_id":989313121,"push_id":25406624311,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"b1056fddc892f6b917c17614dfa7c37549a28e97","before":"2a0a4ba25ea1d1bfc9d0e41500bcb37bbf01db7d","commits":[{"sha":"b1056fddc892f6b917c17614dfa7c37549a28e97","author":{"email":"ahmed123@gmial.com","name":"ahmed"},"message":"AddingSecondIdentity","distinct":true,"url":"https://api.github.com/repos/ahmed18837/RestaurantsManagementSystem/commits/b1056fddc892f6b917c17614dfa7c37549a28e97"}]},"public":true,"created_at":"2025-07-10T06:35:30Z"},{"id":"51910975190","type":"PushEvent","acto
# ...
